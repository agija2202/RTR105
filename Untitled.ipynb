# %%
#1.labors
#Ielādējam savu repozitāriju terminālā un islēdzam  idle & vidi kur sākam veidot funkciju 

from math import *
# importēt matemātiku importēs matemātikas moduli. 
#Jebkuras funkcijas, ko jūs izmantojat,būtu jāizmanto kā math.sqrt, math.ceil utt.
#No matemātikas importēšanas * importēs visas funkcijas no matemātikas. Visas funkcijas, ko izmantojat.
 
x = float (input("Lietotāj , lūdzu . idavadi argumentu (x): "))
# ievadām  frazi kura pieprasa mums x vērtību float un input mums izvada to uz ekrāna

print("x = %.2f sin(x) = %.2f"%(x,sin(x))) 
# izvadām pieprasītā skaitļa sīnusu ,print – tas ar ko mēs pieprasām izvadīt doto iekavās informāciju uz ekrāna 

y = sin(x)
print("             500")
print("          ---------")
print("          \\                       2*k+1")
print ("           \\                    k ")                

print ("sin(x) = |            -------------------------")   
print ("           /                     (2*k+1)! ")
print("          /")
print("          ---------")
print("           k = 0")

#Terminālā ievadām vārdu -nano ,kur attelojam doto funkcijas izskatu izmantojot  
#vārdu  print pieprasām programmu izvadīt  ievadītās zīmes.Nano vidē mēs tikai attelojam  funkcijas izskatu, 
#bet tad to iekopējam un ievadām idel& vidē lai rezultātā saņemtu funkciju .
                             

print("sin(%.2f) = %.2f"%(x,y))
a0 = (x)**1/(1)
S0 = a0
print("a0 = %.2f S0 = %.2f"%(a0,S0))

a1 = (x)**3/(1*2*3)
S1 = a0 + a1
print("a1 = %.2f S1 = %.2f"%(a1,S1))

a2 = (x)**5/(1*2*3*4*5)
S2 = a0 + a1 + a2
print("a2 = %.2f S2 = %.2f"%(a2,S2))

a3 = (x)**7/(1*2*3*4*5*6*7)
S3 = a0 + a1 + a2 + a3
print("a3 = %.2f S3 = %.2f"%(a3,S3))

#Pēc šī pierakst mēs izsecinam to , ka a0= 

#X  pakāpē 1 dalīt ar 1 , un tā pat ievietojot skaitļus no 0 līdz 3 un iegustām vēlamo rezultātu 


x = float (input("Lietotāj , lūdzu , ievadi argumentu (x): "))
y = sin(x)
#Velreiz pieprasām lietotāju ievadīt skaitli formulā sin(x)
print("sin(%.2f) = %.2f"%(x,y))
a0 = (x)**1/(1)
S = a0
print("a0 = %.2f S0 = %.2f"%(a0,S0))

S = S + a1
print("a1 = %.2f S1 = %.2f"%(a1,S))

a2 = (x)**5/(1*2*3*4*5)
S = S + a2
print("a2 = %.2f S2 = %.2f"%(a2,S))

a3 = (x)**7/(1*2*3*4*5*6*7)
S3 = S + a3
print("a3 = %.2f S3 = %.2f"%(a3,S))
#print("sin(%.2f) = %.2f"%(x,y))
a0 = (x)**1/(1)
S = a0
print("a0 = %.2f S0 = %.2f"%(a0,S0))

S = S + a1
print("a1 = %.2f S1 = %.2f"%(a1,S))

a2 = (x)**5/(1*2*3*4*5)
S = S + a2
print("a2 = %.2f S2 = %.2f"%(a2,S))

a3 = (x)**7/(1*2*3*4*5*6*7)
S3 = S + a3
print("a3 = %.2f S3 = %.2f"%(a3,S))
#Izmantojot citas funkcijqas sistēma aprēkina to pēc ievadītā skaitļa nu uz ekrāna izdod atbildi
# Out:
# Lietotāj , lūdzu . idavadi argumentu (x): 0.27
# x = 0.27 sin(x) = 0.27
#              500
#           ---------
#           \                       2*k+1
#            \                    k
# sin(x) = |            -------------------------
#            /                     (2*k+1)!
#           /
#           ---------
#            k = 0
# sin(0.27) = 0.27
# a0 = 0.27 S0 = 0.27
# a1 = 0.00 S1 = 0.27
# a2 = 0.00 S2 = 0.27
# a3 = 0.00 S3 = 0.27
# Lietotāj , lūdzu , ievadi argumentu (x): 98
# sin(98.00) = -0.57
# a0 = 98.00 S0 = 0.27
# a1 = 0.00 S1 = 98.00
# a2 = 75326733.07 S2 = 75326831.07
# a3 = 17224712961.24 S3 = 75326831.07
# a0 = 98.00 S0 = 0.27
# a1 = 0.00 S1 = 98.00
# a2 = 75326733.07 S2 = 75326831.07
# a3 = 17224712961.24 S3 = 75326831.07
